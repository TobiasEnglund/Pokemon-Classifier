# %% [markdown]
# ## Augmentation Test (SimpleCNN, 20 Epochs)
#
# ### Baseline
# - **Test Accuracy:** 69.40%
#
# ---
#
# ### Torch Augmentations
#
# - **All**
#   Test Accuracy: 62.64%
#
# - **Only RandomResizedCrop**
#   Test Accuracy: 56.34%
#
# - **Only RandomHorizontalFlip**
#   Test Accuracy: 68.72%
#
# - **Only RandomRotation**
#   Test Accuracy: 54.31%
#
# - **Only RandomAdjustSharpness**
#   Test Accuracy: 59.37%
#
# ---
#
# ### Albumentations Augmentations
#
# - **All**
#   Test Accuracy: 66.59%
#
# - **Only RandomRotate90**
#   Test Accuracy: 67.15%
#
# - **Only HorizontalFlip**
#   Test Accuracy: 71.13%
#
# - **Only VerticalFlip**
#   Test Accuracy: 68.69%
#
# - **Only ShiftScaleRotate**
#   Test Accuracy: 63.82%
#
# - **Only RandomBrightnessContrast**
#   Test Accuracy: 75.02%
#
# - **Only HueSaturationValue**
#   Test Accuracy: 77.37%
#
# - **Only ColorJitter**
#   Test Accuracy: 74.78%
#
# - **Only GaussNoise**
#   Test Accuracy: 72.18%
#
# - **Only GaussianBlur**
#   Test Accuracy: 68.72%
#
# - **Only MotionBlur**
#   Test Accuracy: 64.65%
#
# - **CoarseDropout**
#   Test Accuracy: 72.28%
#
# ---
#
# #### Combination experiments
#
# - **HueSaturationValue + RandomBrightnessContrast**
#   Test Accuracy: 77.06%
#
# - **HueSaturationValue + RandomBrightnessContrast + GaussNoise + ColorJitter**
#   Test Accuracy: 76.97%
#
# - **HueSaturationValue + RandomBrightnessContrast + GaussNoise + HorizontalFlip**
#   Test Accuracy: 73.70%
#
# - **HueSaturationValue + RandomBrightnessContrast + GaussNoise**
#   Test Accuracy: 76.32%
#
# - **HueSaturationValue + RandomBrightnessContrast + HorizontalFlip**
#   Test Accuracy: 72.06%
#
# ---
#
# ## Result
#
# The Torch augmentations resulted in lower accuracy than baseline. Albumentations performed a lot better, so we'll go with that.
# I will go with **HueSaturationValue + RandomBrightnessContrast + ColorJitter + GaussNoise**.
#
# - **HueSaturationValue, RandomBrightnessContrast, and ColorJitter** got top accuracy and suit well for Pokémon images, which have a lot of color variations.
# - **GaussNoise** adds robustness to the model and helps avoid overfitting.
